# %%
import pandas as pd
import numpy as np
from CNN import CNN
# Out:
# <module 'CNN' from '/Users/niklas/Python/AI/CNN.py'>

# %%
train = pd.read_csv("/Data/digit_train.csv").values
X_train = train[:40000, 1:]
y_train = train[:40000, 0]
X_test = train[40000:, 1:]
y_test = train[40000:, 0]
# Out:
# (42000,) (42000, 784)

# %%
structure = [
    ["conv", 1, 4, 3],
    ["pool", 2],
    ["conv", 4, 8, 3],
    ["FC", 1568, 512, False],
    ["FC", 512, 256, False],
    ["FC", 256, 10, True]
]


model = CNN(structure,
            epochs=75,
            batch_size=100,
            learning_rate=0.0005,
            colour_channels=1,
            picture_h=28,
            picture_w=28,
            adam=True,
            dropout=0.4
            )
model.fit(X_train, y_train)
# Out:
# 0 1.1660052618607657
# 1 0.26141942635663656
# 2 0.1607186296178389
# 3 0.1176199985912127
# 4 0.08792204285814614
# 5 0.0709680772448192
# 6 0.05511910144794463
# 7 0.04778797107572769
# 8 0.041715160549203864
# 9 0.04030784497421779
# 10 0.035821772224693293
# 11 0.029491975303091774
# 12 0.028867885080641302
# 13 0.026500221331682464
# 14 0.023552984488448312
# 15 0.02541447234221659
# 16 0.02230877649832887
# 17 0.017682317117974335
# 18 0.02030317810907772
# 19 0.018832726141992592
# 20 0.020535922508891653
# 21 0.017713008966855334
# 22 0.017737604278399505
# 23 0.013164837398292023
# 24 0.01235616442043271
# 25 0.01538138464188024
# 26 0.01824470088334321
# 27 0.012733460100875784
# 28 0.012257723834356487
# 29 0.012829003533121186
# 30 0.013228425928330149
# 31 0.010533017313613035
# 32 0.008379644025599755
# 33 0.011145376161024656
# 34 0.010615669567826174
# 35 0.013748104675596078
# 36 0.011455335616418854
# 37 0.008445212249164715
# 38 0.009915704770214261
# 39 0.009525387657196216
# 40 0.010280433254214136
# 41 0.00991748665319573
# 42 0.010423542012262596
# 43 0.008295058699209224
# 44 0.0070383836657430445
# 45 0.007797757402009122
# 46 0.007094223001409368
# 47 0.008485058915577054
# 48 0.009212524170754783
# 49 0.009765786602237996
# 50 0.009622662334226284
# 51 0.007474273383386661
# 52 0.006004302371379853
# 53 0.00874781009778677
# 54 0.007370291813503536
# 55 0.00829359927206049
# 56 0.0062585978714532935
# 57 0.009979534927851459
# 58 0.004491881888172023
# 59 0.009125848863690975
# 60 0.0034427816114931827
# 61 0.006719158797168648
# 62 0.006776373393260775
# 63 0.008343340427107456
# 64 0.0067906095003923035
# 65 0.007180581599090812
# 66 0.006037949328135741
# 67 0.006030361988922824
# 68 0.0054860072394802605
# 69 0.009068685023117737
# 70 0.005925672243380549
# 71 0.0065321249535080115
# 72 0.007022533716833628
# 73 0.007406123362211272
# 74 0.004653333944631116

# %%
y_pred_train = model.predict(X_train)
print(f"Training accuracy: {round(np.mean(y_pred_train == y_train) * 100, 1)}%")
y_pred_test = model.predict(X_test)
print(f"Test accuracy: {round(np.mean(y_pred_test == y_test) * 100, 1)}%")
# Out:
# Training accuracy: 100.0%
# Test accuracy: 100.0%
